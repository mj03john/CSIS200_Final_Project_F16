# %%
# Edit this cell to print out your name.
print "My name is %s" % ("Matthew Johnson")

# %% [markdown]
# # Predicting the weather
#
# ***For all of the questions in this project, assume that 1 month = 30 days.***

# %% [markdown]
# ## Problem 1 (20 pts)
#
# Suppose there is a 20% chance it will rain on any given day in a month. What are the odds that that rains on one and only one day in a month.
#
# Work this problem out a*nalytically* (with pen and paper, using a formula) and write it up in your final document.
#
# Here you should solve the same problem *numerically* using a Monte Carlo approach, similar to how we approached the birthday problem in class.
#
# Make sure that both approaches give you a similar result.

# %%
# Your code here
import numpy as np
import matplotlib.pylab as plt

# %matplotlib notebook
dr=1
dnr=29
rain = 0
def oddnorain():
    odd = (((0.2**dr)*(0.8**dnr))*100)*30
    
    return odd
print oddnorain()
# Out:
# 0.928455029464

# %%
import numpy as np
days =30

def rain_day():
    day = np.random.random()
    if day <=0.2:
            rain = 1
    else:
            rain = 0 
    return rain



 
def days_it_rain(days=30):
    rain_days = 0
    
    
    for i in range (0,days):
        value = rain_day()
        rain_days += (value)
    return rain_days


months = 10000
def month_1_rain():
    one_rain = 0.0
   
    for i in range (0,months):
        value = days_it_rain()
        if value==1:
            one_rain += 1
        value = 0
    return one_rain

print  ((month_1_rain())/(months))*100
# Out:
# 0.95

# %% [markdown]
# ## Problem 2 (20 pts)
#
# Suppose there is a 10% chance that it will rain on any given day in a month. What are the odds that it rains at least 8 days (in any order) that month?
#
# Work this problem out *numerically* using a Monte Carlo approach.

# %%
# Your code here
import numpy as np
days =30

def rain_day():
    day = random.random()
    if day <=0.1:
            rain = 1
    else:
            rain = 0 
    return rain



days = 30 
def days_it_rain():
    rain_days = 0
    days = 30
    
    for i in range (0,days):
        value = rain_day()
        rain_days += (value)
    return rain_days


months = 10000
def month_1_rain():
    one_rain = 0.0
    for i in range (0,months):
        value = days_it_rain()
        if value >=8:
            one_rain += 1
        value = 0
    return one_rain
print  ((month_1_rain())/(months))*100

# %% [markdown]
# ## Problem 3
#
# ### 3a (20 pts)
#
# Suppose that if it rains one day, the odds of a certain amount of rainfall *on that day* are
#
# * 1 cm   20%
# * 2 cm   30%
# * 3 cm   30%
# * 4 cm   10%
# * 5 cm   10%
#
# However the odds of it raining are dependent on if it rained the day before.
#
# * If it is the first day of the month, there is a 10% chance of rain.
# * If it rained 1 day before, but not 2 days before, there is a 20% chance of rain.
# * If it rained both of the 2 days before, but not the 3rd day before, there is a 25% chance of rain.
# * If it rained for the 3 days (or more) before, there is a 5% chance of rain.
# * Otherwise, there is a 10% chance of rain
#
# What are the odds that there are at least 10 cm of rain in a given month?
#
# Work this problem out using a Monte Carlo approach.

# %%
#set array of 30 zero represent if rain 
#loop over first rain 
#if rain set first day one 1 
#if first day was 1 
#i 
#look at previous list i -1

def rain_day2():
    
    day = np.random.random()
    if day <=0.2:
            rain = 1
    else:
            rain = 0 
    return rain
def rain_day3():
    day = np.random.random()
    if day <=0.25:
            rain = 1
    else:
            rain = 0 
    return rain
def rain_day4():
    day = np.random.random()
    if day <=0.05:
            rain = 1
    else:
        
            rain = 0 
    return rain
def amt_rain():
    amt=np.random.random()
    if amt <= 0.2:
        rainamt = 1
    elif amt >0.2 and amt <= 0.5:
        rainamt = 2 
    elif amt > 0.5 and amt <=0.8:
        rainamt = 3
    elif amt >0.8 and amt <=0.9:
        rainamt = 4 
    elif amt >0.9 and amt <=1:
        rainamt = 5 
    return rainamt

# %%
def will_it_rn():
    days = []
    rain = 0.0 
    rainamt=[]
    for i in range(0,30):
        days.append (rain)
        i += 1 
    for i in range(0,30):
        rainamt.append (rain)
        i += 1 
    for i in range (0,30):
   
    
        if i==1 and rain_day()==1:
            days[0]=1
            rainamt[0]=amt_rain()
            i+=1
        if i==2 and days[0]==1 and rain_day2()==1:#day 2
            days[1]=1
            rainamt[1]=amt_rain()
            i+=1
        if i==2 and days[0]==0 and rain_day()==1:#day 2
            days[1]=1
            rainamt[1]=amt_rain()
            i+=1
        if i==3 and days[0]==1 and days[1]==1 and rain_day3()==1:
            days[2]=1
            rainamt[2]=amt_rain()
            i+=1
        
        if i==3 and days[0]==0 and days[1]==1 and rain_day2()==1:
            days[2]=1
            rainamt[2]=amt_rain()
            i+=1
            #return rainamt
        if i==3 and days[0]==0 and days[1]==0 and rain_day()==1:
            days[2]=1
            rainamt[2]=amt_rain()
            i+=1
        if i==4 and days[0]==1 and days[1]==1 and days[2]==1 and rain_day4()==1:
            days[3]=1
            rainamt[3]=amt_rain()
            i+=1
        if i==4 and days[0]==1 and days[1]==1 and days[2]==0 and rain_day3()==1:
            days[3]=1
            rainamt[3]=amt_rain()
            i+=1
        if i==4 and days[0]==1 and days[1]==0 and days[2]==0 and rain_day2()==1:
            days[3]=1
            rainamt[3]=amt_rain()
            i+=1
        if i==4 and days[0]==0 and days[1]==0 and days[2]==0 and rain_day()==1:
            days[3]=1
            rainamt[3]=amt_rain()
            i+=1
        if i>=5 and days[i-3]==1 and days[i-2]==1 and days[i-1]==1 and rain_day4()==1:
            days[i]=1
            rainamt[i]=amt_rain()
            i+=1
        if i>=5 and days[i-3]==0 and days[i-2]==1 and days[i-1]==1 and rain_day3()==1:
            days[i]=1
            rainamt[i]=amt_rain()
            i+=1
        if i>=5 and days[i-3]==0 and days[i-2]==0 and days[i-1]==1 and rain_day2()==1:
            days[i]=1
            rainamt[i]=amt_rain()
            i+=1
        if i>=5 and days[i-3]==0 and days[i-2]==0 and days[i-1]==0 and rain_day()==1:
            days[i]=1
            rainamt[i]=amt_rain()
            i+=1
        
       
    return sum(rainamt)

# %%
months=10000
def month_10cm_rain():
    one_rain = 0.0
    for i in range (0,months):
        
        if will_it_rn() >=10:
            one_rain += 1
            i +=1
       

    return one_rain
print  ((month_10cm_rain())/(months))*100
# Out:
# 66.04

# %% [markdown]
# ### 3b (10 pts)
#
# Make a histogram of the distribtion of expected rainfall values. You can get this from your Monte Carlo trials.
#
# Make sure you label everything clearly.

# %%
# Your code here


months = 10000 # The number of times we roll the die

rain = []
for i in range(0,months):
    
    value = will_it_rn()
    rain.append(value)
    
plt.figure(figsize=(5,5))

plt.hist(rain,bins=6,range=(0,39)) 


plt.xlabel("Amount of rain in a month(cm)",fontsize=18)
plt.ylabel("# of occurances",fontsize=18)

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### 3c (10 pts)
#
# What is the average amount of rain to fall in any given month?

# %%
# Your code here?
def average(months=10000):
   
    sum = 0.0 
    for i in range(0,months):
        sum+= will_it_rn()
        i+=1
    return sum/months
print average()
# Out:
# 12.0334

# %% [markdown]
# ### 3d (20)
#
# Once you find the average value, someone might ask you for the uncertainty (some people also refer to uncertainty as the "*error*") on your prediction. That can be tricky to calculate, so often what is given is just a *range* of possible values. "We estimate the rainfall to be between X cm and Y cm." The question is, how to decide what that range is.
#
# The way this is often done is to find the middle 95% of the trial values (from your Monte Carlo run) and then use the low-edge and the high-edge of that range. If you're concerned about the middle 95%, then 2.5% of the values are below them and 2.5% of all the values are above them. The rainfall values at those edges are what you use for the ranges to quote.
#
# This is what people mean when they say, "I'm 95% confident that the rainfall will be between X and Y", and when you write it up for the LaTeX document, you should also quote it this way.
#
# *Hint!* This part becomes much easier if you sort all the values using any of the numpy/Python sort functions you can read about online. When you sort them, you should be able to find what rainfall is at the edge for the lower 2.5% and the higher 2.5%.

# %%
# Your code here
